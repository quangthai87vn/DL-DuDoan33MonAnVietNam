# %%
# ====== CẤU HÌNH TOÀN CỤC ======
from pathlib import Path
import time, os
import torch
import torch.nn as nn
from torchvision.models import efficientnet_b0, EfficientNet_B0_Weights



class MTL_EfficientNetB0(nn.Module):
    def __init__(self, num_classes=33):
        super().__init__()
        self.backbone = efficientnet_b0(weights=EfficientNet_B0_Weights.IMAGENET1K_V1)
        in_features = self.backbone.classifier[1].in_features
        self.backbone.classifier[1] = nn.Linear(in_features, num_classes)

    def forward(self, x):
        return self.backbone(x)

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

import os
import sys

# Thêm đường dẫn tới thư mục /model
sys.path.append("/model")
from model.mtl_efficientnet_b0 import MTL_EfficientNetB0

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

checkpoint_path = "/Jupyter/runs/MTL_TGFOOD_01/checkpoints/mtl_effcientnet_b0_best.pt"
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 11
#       9 # Thêm đường dẫn tới thư mục /model
#      10 sys.path.append("/model")
# ---> 11 from model.mtl_efficientnet_b0 import MTL_EfficientNetB0
#      13 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#      15 checkpoint_path = "/Jupyter/runs/MTL_TGFOOD_01/checkpoints/mtl_effcientnet_b0_best.pt"
#
# ModuleNotFoundError: No module named 'model'
